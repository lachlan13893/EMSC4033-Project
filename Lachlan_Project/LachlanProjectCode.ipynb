# %%
from Code.dependencies import *
from Code.my_functions import *

# %%
### Define desired resolution ###
### Choices are: Low, Moderate, High, Very High ###
### Additionally, a specific file can be named if desired e.g. 'Files/GEMT2.gfc' ###
resolution = 'Moderate'

### Based Upon Resolution or Specific named file, Select input ###
input_file = resolution
if resolution == 'Low':
    input_file = 'Files/GEMT2.gfc'
if resolution == 'Moderate':
    input_file = 'Files/GOCO06s.gfc'
if resolution == 'High':
    input_file = 'Files/EIGEN6C2.gfc'
if resolution == 'Very High':
    input_file = 'Files/XGM2019e_2159.gfc'
    
#input_file = 'Files/AIUB-GRL350A.gfc'  #Moon .gfc file
#input_file = 'Files/shgj180ua01.gfc'  #Venus .gfc file

# %%
File_Size(input_file)
# Out:
# Coefficient File: Files/GOCO06s.gfc
# Degree = 300
# Spherical Harmonic degree is Moderate. Estimate will be reasonably quick

# %%
Gravity_Field(input_file)

# %%
Gravity_Field_Limited(input_file)
